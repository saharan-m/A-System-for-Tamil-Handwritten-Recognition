# %%
import os
import h5py
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizersmizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Convolution2D,MaxPooling2D,Activation, Dropout, Flatten, Dense, BatchNormalization

# %%
trainDataGen = ImageDataGenerator(
		rotation_range = 5,
		width_shift_range = 0.1,
		height_shift_range = 0.1,
		rescale = 1.0/255,
		shear_range = 0.2,
		zoom_range = 0.2,		
		horizontal_flip = False,
		fill_mode = 'nearest')

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
trainGenerator = trainDataGen.flow_from_directory(
			"/home/mayank/Downloads/tamil_noninverted/Train",
			target_size = (64,64),
			batch_size = 64,
			color_mode = "grayscale",
			class_mode = "categorical")
# Out:
# Found 61776 images belonging to 156 classes.

# %%
prev = ""
labels = []
for x in range(0,156):
    labels.append(str(x))
count = 0;

# %%
validation_generator = test_datagen.flow_from_directory(
			"/home/mayank/Downloads/tamil_noninverted/Test",
			target_size=(64,64),
			batch_size=64,
			color_mode = "grayscale",
			class_mode= 'categorical')
			
model = Sequential()
# Out:
# Found 10920 images belonging to 156 classes.

# %%
model.add(Convolution2D(filters = 32,
			kernel_size = (3,3),
			strides = 1,
			activation = "relu",
			input_shape = (64,64,1)))

model.add(BatchNormalization())
#model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size=(2, 2),
			strides=(2, 2),
			padding="same"))

#Layer2-------------------------------------------------------------
model.add(Convolution2D(filters = 32,
			kernel_size = (3,3),
			strides = 1,
			activation = "relu",
			input_shape = (64,64,1)))
model.add(BatchNormalization())
#model.add(MaxPooling2D())
model.add(MaxPooling2D(pool_size=(2, 2),
			strides=(2, 2),
			padding="same"))
#model.add(Dropout(0.25))


#Layers 3-----------------------------------------------------------	
model.add(Convolution2D(filters = 64,
			kernel_size = (3,3),
			strides = 1,
			activation = "relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2),
			strides=(2, 2),
			padding="same"))


#Layer 4--------------------------------------------------
model.add(Convolution2D(filters = 64,
			kernel_size = (3,3),
			strides= 1,
			activation = "relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2),
			strides=(2, 2),
			padding="same"))			
			
#model.add(Dropout(0.2))


#Layer 5------------------------------------------------------------
'''model.add(Convolution2D(filters = 64,
			kernel_size = (2,2),
			strides= 1,
			activation = "relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2),
			strides=(2, 2),
			padding="same"))'''


model.add(Flatten())

model.add(Dense(128,
		activation = "relu",
		kernel_initializer = "uniform"))
model.add(BatchNormalization())			

model.add(Dense(64,
		activation = "relu",
		kernel_initializer = "uniform"))
model.add(BatchNormalization())			

model.add(Dense(156,
		activation = "softmax",
		kernel_initializer = "uniform"))			
			
model.compile(optimizer = "adam",
		loss = "categorical_crossentropy",
		metrics = ["accuracy"])
		
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 62, 62, 32)        320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 62, 62, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 29, 29, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 29, 29, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 13, 13, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 5, 5, 64)          36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 5, 5, 64)          256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 128)               512
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64)                256
# _________________________________________________________________
# dense_2 (Dense)              (None, 156)               10140
# =================================================================
# Total params: 158,780
# Trainable params: 158,012
# Non-trainable params: 768
# _________________________________________________________________
# None

# %%
res=model.fit_generator(
		trainGenerator,
		epochs = 100,
		steps_per_epoch = 965,
		validation_data = validation_generator,
		validation_steps = 170
		)
# Out:
# WARNING:tensorflow:From <ipython-input-7-31b3a0cdca5f>:1: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 965/965 [==============================] - 1116s 1s/step - loss: 2.1690 - accuracy: 0.4893 - val_loss: 0.7348 - val_accuracy: 0.7771
# Epoch 2/100
# 965/965 [==============================] - 653s 676ms/step - loss: 0.8444 - accuracy: 0.7550 - val_loss: 1.6941 - val_accuracy: 0.5626
# Epoch 3/100
# 965/965 [==============================] - 439s 455ms/step - loss: 0.6834 - accuracy: 0.7995 - val_loss: 1.0045 - val_accuracy: 0.7258
# Epoch 4/100
# 965/965 [==============================] - 185s 192ms/step - loss: 0.6174 - accuracy: 0.8168 - val_loss: 0.3526 - val_accuracy: 0.8898
# Epoch 5/100
# 965/965 [==============================] - 341s 353ms/step - loss: 0.5650 - accuracy: 0.8342 - val_loss: 0.9930 - val_accuracy: 0.7296
# Epoch 6/100
# 965/965 [==============================] - 896s 928ms/step - loss: 0.5387 - accuracy: 0.8422 - val_loss: 0.6707 - val_accuracy: 0.8076
# Epoch 7/100
# 965/965 [==============================] - 909s 942ms/step - loss: 0.5110 - accuracy: 0.8493 - val_loss: 0.3821 - val_accuracy: 0.8800
# Epoch 8/100
# 965/965 [==============================] - 780s 808ms/step - loss: 0.4936 - accuracy: 0.8539 - val_loss: 0.3732 - val_accuracy: 0.8879
# Epoch 9/100
# 965/965 [==============================] - 679s 704ms/step - loss: 0.4646 - accuracy: 0.8624 - val_loss: 1.1201 - val_accuracy: 0.7102
# Epoch 10/100
# 965/965 [==============================] - 670s 694ms/step - loss: 0.4617 - accuracy: 0.8637 - val_loss: 0.3100 - val_accuracy: 0.9024
# Epoch 11/100
# 965/965 [==============================] - 825s 855ms/step - loss: 0.4502 - accuracy: 0.8674 - val_loss: 0.7711 - val_accuracy: 0.7874
# Epoch 12/100
# 965/965 [==============================] - 635s 658ms/step - loss: 0.4336 - accuracy: 0.8710 - val_loss: 0.7348 - val_accuracy: 0.7950
# Epoch 13/100
# 965/965 [==============================] - 494s 512ms/step - loss: 0.4235 - accuracy: 0.8745 - val_loss: 0.7954 - val_accuracy: 0.7783
# Epoch 14/100
# 965/965 [==============================] - 184s 191ms/step - loss: 0.4155 - accuracy: 0.8766 - val_loss: 0.4283 - val_accuracy: 0.8730
# Epoch 15/100
# 965/965 [==============================] - 183s 190ms/step - loss: 0.4056 - accuracy: 0.8792 - val_loss: 0.5345 - val_accuracy: 0.8438
# Epoch 16/100
# 965/965 [==============================] - 180s 186ms/step - loss: 0.3971 - accuracy: 0.8821 - val_loss: 1.6099 - val_accuracy: 0.6428
# Epoch 17/100
# 965/965 [==============================] - 182s 188ms/step - loss: 0.3880 - accuracy: 0.8852 - val_loss: 0.2695 - val_accuracy: 0.9190
# Epoch 18/100
# 965/965 [==============================] - 182s 189ms/step - loss: 0.3819 - accuracy: 0.8855 - val_loss: 0.4212 - val_accuracy: 0.8817
# Epoch 19/100
# 965/965 [==============================] - 188s 195ms/step - loss: 0.3785 - accuracy: 0.8856 - val_loss: 1.2941 - val_accuracy: 0.7042
# Epoch 20/100
# 965/965 [==============================] - 184s 190ms/step - loss: 0.3710 - accuracy: 0.8889 - val_loss: 0.8875 - val_accuracy: 0.7735
# Epoch 21/100
# 965/965 [==============================] - 183s 189ms/step - loss: 0.3675 - accuracy: 0.8878 - val_loss: 0.3328 - val_accuracy: 0.9017
# Epoch 22/100
# 965/965 [==============================] - 185s 191ms/step - loss: 0.3597 - accuracy: 0.8910 - val_loss: 0.5621 - val_accuracy: 0.8407
# Epoch 23/100
# 965/965 [==============================] - 187s 194ms/step - loss: 0.3554 - accuracy: 0.8921 - val_loss: 0.9415 - val_accuracy: 0.7625
# Epoch 24/100
# 965/965 [==============================] - 186s 193ms/step - loss: 0.3469 - accuracy: 0.8961 - val_loss: 0.7261 - val_accuracy: 0.8085
# Epoch 25/100
# 965/965 [==============================] - 185s 191ms/step - loss: 0.3431 - accuracy: 0.8961 - val_loss: 0.3496 - val_accuracy: 0.8938
# Epoch 26/100
# 965/965 [==============================] - 187s 193ms/step - loss: 0.3421 - accuracy: 0.8948 - val_loss: 0.5303 - val_accuracy: 0.8525
# Epoch 27/100
# 965/965 [==============================] - 184s 191ms/step - loss: 0.3368 - accuracy: 0.8979 - val_loss: 0.7676 - val_accuracy: 0.8031
# Epoch 28/100
# 965/965 [==============================] - 185s 192ms/step - loss: 0.3318 - accuracy: 0.8983 - val_loss: 0.9024 - val_accuracy: 0.7702
# Epoch 29/100
# 965/965 [==============================] - 196s 203ms/step - loss: 0.3287 - accuracy: 0.8989 - val_loss: 0.4383 - val_accuracy: 0.8687
# Epoch 30/100
# 965/965 [==============================] - 195s 202ms/step - loss: 0.3263 - accuracy: 0.9006 - val_loss: 0.3139 - val_accuracy: 0.9053
# Epoch 31/100
# 965/965 [==============================] - 192s 199ms/step - loss: 0.3251 - accuracy: 0.8992 - val_loss: 0.3041 - val_accuracy: 0.9051
# Epoch 32/100
# 965/965 [==============================] - 199s 206ms/step - loss: 0.3208 - accuracy: 0.9016 - val_loss: 0.6633 - val_accuracy: 0.8216
# Epoch 33/100
# 965/965 [==============================] - 204s 211ms/step - loss: 0.3157 - accuracy: 0.9031 - val_loss: 0.3623 - val_accuracy: 0.8943
# Epoch 34/100
# 965/965 [==============================] - 198s 206ms/step - loss: 0.3162 - accuracy: 0.9033 - val_loss: 0.2503 - val_accuracy: 0.9256
# Epoch 35/100
# 965/965 [==============================] - 396s 410ms/step - loss: 0.3125 - accuracy: 0.9023 - val_loss: 0.2834 - val_accuracy: 0.9148
# Epoch 36/100
# 965/965 [==============================] - 259s 268ms/step - loss: 0.3107 - accuracy: 0.9025 - val_loss: 0.6628 - val_accuracy: 0.8232
# Epoch 37/100
# 965/965 [==============================] - 204s 211ms/step - loss: 0.3046 - accuracy: 0.9060 - val_loss: 0.3988 - val_accuracy: 0.8869
# Epoch 38/100
# 965/965 [==============================] - 186s 193ms/step - loss: 0.3071 - accuracy: 0.9056 - val_loss: 0.5234 - val_accuracy: 0.8585
# Epoch 39/100
# 965/965 [==============================] - 189s 195ms/step - loss: 0.2999 - accuracy: 0.9074 - val_loss: 0.6499 - val_accuracy: 0.8324
# Epoch 40/100
# 965/965 [==============================] - 187s 193ms/step - loss: 0.2974 - accuracy: 0.9080 - val_loss: 0.2964 - val_accuracy: 0.9114
# Epoch 41/100
# 965/965 [==============================] - 188s 195ms/step - loss: 0.2969 - accuracy: 0.9062 - val_loss: 0.3150 - val_accuracy: 0.9071
# Epoch 42/100
# 965/965 [==============================] - 185s 192ms/step - loss: 0.2959 - accuracy: 0.9079 - val_loss: 0.4170 - val_accuracy: 0.8791
# Epoch 43/100
# 965/965 [==============================] - 190s 197ms/step - loss: 0.2903 - accuracy: 0.9098 - val_loss: 0.3756 - val_accuracy: 0.8836
# Epoch 44/100
# 965/965 [==============================] - 194s 201ms/step - loss: 0.2921 - accuracy: 0.9085 - val_loss: 0.4689 - val_accuracy: 0.8663
# Epoch 45/100
# 965/965 [==============================] - 193s 200ms/step - loss: 0.2847 - accuracy: 0.9105 - val_loss: 0.3158 - val_accuracy: 0.9062
# Epoch 46/100
# 965/965 [==============================] - 196s 203ms/step - loss: 0.2860 - accuracy: 0.9100 - val_loss: 0.3662 - val_accuracy: 0.8948
# Epoch 47/100
# 965/965 [==============================] - 193s 200ms/step - loss: 0.2843 - accuracy: 0.9115 - val_loss: 0.3599 - val_accuracy: 0.8966
# Epoch 48/100
# 965/965 [==============================] - 192s 199ms/step - loss: 0.2841 - accuracy: 0.9104 - val_loss: 0.3629 - val_accuracy: 0.8959
# Epoch 49/100
# 965/965 [==============================] - 197s 204ms/step - loss: 0.2791 - accuracy: 0.9126 - val_loss: 0.6906 - val_accuracy: 0.8250
# Epoch 50/100
# 965/965 [==============================] - 198s 206ms/step - loss: 0.2769 - accuracy: 0.9128 - val_loss: 0.3628 - val_accuracy: 0.8936
# Epoch 51/100
# 965/965 [==============================] - 200s 208ms/step - loss: 0.2748 - accuracy: 0.9133 - val_loss: 0.3423 - val_accuracy: 0.9007
# Epoch 52/100
# 965/965 [==============================] - 190s 196ms/step - loss: 0.2735 - accuracy: 0.9126 - val_loss: 0.2943 - val_accuracy: 0.9144
# Epoch 53/100
# 965/965 [==============================] - 190s 197ms/step - loss: 0.2773 - accuracy: 0.9120 - val_loss: 0.5224 - val_accuracy: 0.8586
# Epoch 54/100
# 965/965 [==============================] - 191s 198ms/step - loss: 0.2719 - accuracy: 0.9151 - val_loss: 0.3539 - val_accuracy: 0.8982
# Epoch 55/100
# 965/965 [==============================] - 193s 200ms/step - loss: 0.2690 - accuracy: 0.9151 - val_loss: 0.6097 - val_accuracy: 0.8313
# Epoch 56/100
# 965/965 [==============================] - 194s 201ms/step - loss: 0.2679 - accuracy: 0.9162 - val_loss: 0.4133 - val_accuracy: 0.8807
# Epoch 57/100
# 965/965 [==============================] - 195s 203ms/step - loss: 0.2663 - accuracy: 0.9149 - val_loss: 0.2594 - val_accuracy: 0.9233
# Epoch 58/100
# 965/965 [==============================] - 192s 199ms/step - loss: 0.2644 - accuracy: 0.9157 - val_loss: 0.6458 - val_accuracy: 0.8297
# Epoch 59/100
# 965/965 [==============================] - 192s 198ms/step - loss: 0.2659 - accuracy: 0.9167 - val_loss: 0.3780 - val_accuracy: 0.8942
# Epoch 60/100
# 965/965 [==============================] - 187s 194ms/step - loss: 0.2577 - accuracy: 0.9186 - val_loss: 0.4800 - val_accuracy: 0.8733
# Epoch 61/100
# 965/965 [==============================] - 181s 187ms/step - loss: 0.2667 - accuracy: 0.9163 - val_loss: 0.4101 - val_accuracy: 0.8817
# Epoch 62/100
# 965/965 [==============================] - 187s 194ms/step - loss: 0.2615 - accuracy: 0.9173 - val_loss: 0.5180 - val_accuracy: 0.8574
# Epoch 63/100
# 965/965 [==============================] - 189s 196ms/step - loss: 0.2629 - accuracy: 0.9156 - val_loss: 1.0111 - val_accuracy: 0.7659
# Epoch 64/100
# 965/965 [==============================] - 189s 195ms/step - loss: 0.2587 - accuracy: 0.9182 - val_loss: 0.4433 - val_accuracy: 0.8790
# Epoch 65/100
# 965/965 [==============================] - 181s 188ms/step - loss: 0.2552 - accuracy: 0.9171 - val_loss: 0.2968 - val_accuracy: 0.9131
# Epoch 66/100
# 965/965 [==============================] - 180s 187ms/step - loss: 0.2574 - accuracy: 0.9185 - val_loss: 0.4664 - val_accuracy: 0.8699
# Epoch 67/100
# 965/965 [==============================] - 180s 186ms/step - loss: 0.2563 - accuracy: 0.9174 - val_loss: 0.3831 - val_accuracy: 0.8926
# Epoch 68/100
# 965/965 [==============================] - 180s 187ms/step - loss: 0.2525 - accuracy: 0.9193 - val_loss: 0.3868 - val_accuracy: 0.8922
# Epoch 69/100
# 965/965 [==============================] - 187s 194ms/step - loss: 0.2535 - accuracy: 0.9198 - val_loss: 0.7414 - val_accuracy: 0.8137
# Epoch 70/100
# 965/965 [==============================] - 184s 191ms/step - loss: 0.2516 - accuracy: 0.9198 - val_loss: 0.4961 - val_accuracy: 0.8672
# Epoch 71/100
# 965/965 [==============================] - 193s 200ms/step - loss: 0.2479 - accuracy: 0.9210 - val_loss: 0.4727 - val_accuracy: 0.8682
# Epoch 72/100
# 965/965 [==============================] - 191s 198ms/step - loss: 0.2477 - accuracy: 0.9218 - val_loss: 0.3704 - val_accuracy: 0.8949
# Epoch 73/100
# 965/965 [==============================] - 193s 200ms/step - loss: 0.2500 - accuracy: 0.9203 - val_loss: 0.6548 - val_accuracy: 0.8331
# Epoch 74/100
# 965/965 [==============================] - 194s 201ms/step - loss: 0.2467 - accuracy: 0.9223 - val_loss: 0.4701 - val_accuracy: 0.8659
# Epoch 75/100
# 965/965 [==============================] - 196s 203ms/step - loss: 0.2453 - accuracy: 0.9217 - val_loss: 0.5528 - val_accuracy: 0.8534
# Epoch 76/100
# 965/965 [==============================] - 198s 205ms/step - loss: 0.2452 - accuracy: 0.9216 - val_loss: 0.4125 - val_accuracy: 0.8881
# Epoch 77/100
# 965/965 [==============================] - 198s 205ms/step - loss: 0.2422 - accuracy: 0.9223 - val_loss: 0.3493 - val_accuracy: 0.8999
# Epoch 78/100
# 965/965 [==============================] - 193s 200ms/step - loss: 0.2443 - accuracy: 0.9226 - val_loss: 0.5355 - val_accuracy: 0.8629
# Epoch 79/100
# 965/965 [==============================] - 200s 207ms/step - loss: 0.2445 - accuracy: 0.9214 - val_loss: 0.4831 - val_accuracy: 0.8665
# Epoch 80/100
# 965/965 [==============================] - 203s 211ms/step - loss: 0.2383 - accuracy: 0.9232 - val_loss: 0.3749 - val_accuracy: 0.8983
# Epoch 81/100
# 965/965 [==============================] - 199s 206ms/step - loss: 0.2377 - accuracy: 0.9228 - val_loss: 0.5623 - val_accuracy: 0.8535
# Epoch 82/100
# 965/965 [==============================] - 194s 201ms/step - loss: 0.2393 - accuracy: 0.9221 - val_loss: 0.4572 - val_accuracy: 0.8721
# Epoch 83/100
# 965/965 [==============================] - 187s 193ms/step - loss: 0.2355 - accuracy: 0.9249 - val_loss: 0.3904 - val_accuracy: 0.8905
# Epoch 84/100
# 965/965 [==============================] - 190s 197ms/step - loss: 0.2308 - accuracy: 0.9244 - val_loss: 0.6047 - val_accuracy: 0.8415
# Epoch 85/100
# 965/965 [==============================] - 193s 200ms/step - loss: 0.2348 - accuracy: 0.9248 - val_loss: 0.4361 - val_accuracy: 0.8741
# Epoch 86/100
# 965/965 [==============================] - 188s 194ms/step - loss: 0.2372 - accuracy: 0.9228 - val_loss: 0.6253 - val_accuracy: 0.8438
# Epoch 87/100
# 965/965 [==============================] - 190s 197ms/step - loss: 0.2386 - accuracy: 0.9228 - val_loss: 0.8450 - val_accuracy: 0.7990
# Epoch 88/100
# 965/965 [==============================] - 183s 190ms/step - loss: 0.2354 - accuracy: 0.9241 - val_loss: 1.3542 - val_accuracy: 0.7164
# Epoch 89/100
# 965/965 [==============================] - 184s 191ms/step - loss: 0.2319 - accuracy: 0.9254 - val_loss: 0.4287 - val_accuracy: 0.8815
# Epoch 90/100
# 965/965 [==============================] - 176s 183ms/step - loss: 0.2327 - accuracy: 0.9242 - val_loss: 0.4547 - val_accuracy: 0.8780
# Epoch 91/100
# 965/965 [==============================] - 186s 192ms/step - loss: 0.2320 - accuracy: 0.9252 - val_loss: 0.3969 - val_accuracy: 0.8881
# Epoch 92/100
# 965/965 [==============================] - 195s 202ms/step - loss: 0.2296 - accuracy: 0.9261 - val_loss: 0.3219 - val_accuracy: 0.9104
# Epoch 93/100
# 965/965 [==============================] - 189s 196ms/step - loss: 0.2231 - accuracy: 0.9285 - val_loss: 0.3059 - val_accuracy: 0.9122
# Epoch 94/100
# 965/965 [==============================] - 190s 197ms/step - loss: 0.2321 - accuracy: 0.9238 - val_loss: 0.5733 - val_accuracy: 0.8517
# Epoch 95/100
# 965/965 [==============================] - 185s 192ms/step - loss: 0.2231 - accuracy: 0.9265 - val_loss: 0.5820 - val_accuracy: 0.8515
# Epoch 96/100
# 965/965 [==============================] - 196s 203ms/step - loss: 0.2255 - accuracy: 0.9273 - val_loss: 0.3873 - val_accuracy: 0.8899
# Epoch 97/100
# 965/965 [==============================] - 188s 195ms/step - loss: 0.2307 - accuracy: 0.9254 - val_loss: 0.3787 - val_accuracy: 0.8933
# Epoch 98/100
# 965/965 [==============================] - 179s 185ms/step - loss: 0.2229 - accuracy: 0.9282 - val_loss: 0.4002 - val_accuracy: 0.8895
# Epoch 99/100
# 965/965 [==============================] - 179s 185ms/step - loss: 0.2264 - accuracy: 0.9263 - val_loss: 0.3281 - val_accuracy: 0.9084
# Epoch 100/100
# 965/965 [==============================] - 185s 192ms/step - loss: 0.2231 - accuracy: 0.9278 - val_loss: 0.5963 - val_accuracy: 0.8539
